# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# %matplotlib inline

# %%
df = pd.read_pickle('RAW DATA')

# %%
df.head()
# Out:
#          account_id  date_start   date_stop        campaign_id  \
# 0  1853108461374541  2018-09-21  2018-09-21  23842989673190493
# 1  1853108461374541  2018-09-13  2018-09-13  23842989673180493
# 2  1853113508040703  2018-09-07  2018-09-07  23842947620540453
# 3  1853113508040703  2018-09-06  2018-09-06  23842947620540453
# 4  1853192158032838  2018-09-14  2018-09-14  23842955738700321
#
#                                            ad_name  \
# 0  Carousel_KB-FirstFavorites_9.05-9.20_gusm000417
# 1     Carousel_DenimDresses-1_9.05-9.20_gusm000417
# 2  Story_IconsOfDenimCarousel_8.27-9.13_gcsm000030
# 3  Story_IconsOfDenimCarousel_8.27-9.13_gcsm000030
# 4                   DPA_Women-W_9.5_tid=brsm001491
#
#                                           adset_name  \
# 0  RMKTEvergreen_09.02_CRM/Decile3_DSK/MBL_Conver...
# 1  PRSPCTEvergreen_09.02_WCA/Visitors(00-30d)_DSK...
# 2  GapForGood_08.01_WCA/Visitors(90-180d)_MBL-sto...
# 3  GapForGood_08.01_WCA/Visitors(90-180d)_MBL-sto...
# ...

# %%
def get_metrics(df):
    df['CPM'] = df['spend']/df['impressions']*1000
